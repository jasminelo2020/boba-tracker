# %% [markdown]
# # Jasmine's 2025 Boba Tracker

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import re
from datetime import datetime
import calplot

# %%
boba_raw = pd.read_csv('data/boba2025.csv')

# %%
boba_raw
# Out:
#      month  day                     store                        drink  \
# 0  january    1  cafe bakery & restaurant           hong kong milk tea
# 1  january    2              1011 sip tea        lychee black milk tea
# 2  january    3                mr sun tea           earl grey milk tea
# 3  january    5           mandro teahouse       jasmine green milk tea
# 4  january    7                  teaspoon       jasmine green milk tea
# 5  january    7                      coco             green tea yakult
# 6  january   12                      coco             green tea yakult
# 7  january   13                     tptea  blended strawberry milk tea
#
#                      toppings               drink name  \
# 0                         NaN                      NaN
# 1                        boba                      NaN
# 2  boba, pudding, grass jelly  three brothers milk tea
# 3                     pudding                      NaN
# 4                        boba           creamy jasmine
# 5                         NaN                      NaN
# 6                         NaN                      NaN
# 7                        boba                      NaN
#
#                     friends   cost  size  rating
# 0  sophia, mom, dad, wai po  $4.75  16oz    8/10
# 1            sophia, wai po  $5.50  16oz    7/10
# 2                     emily  $4.00  22oz  8.5/10
# 3                emily, jas  $5.00  22oz  8.5/10
# 4                      jeff  $6.75  22oz    9/10
# 5                      jeff  $7.50  22oz  7.5/10
# 6                      jeff  $6.25  22oz    8/10
# 7                   anthony  $6.75  22oz    8/10

# %%
boba = boba_raw.copy()

# %%
def get_toppings(toppings):
    if pd.isnull(toppings):
        return ['no topping']
    return toppings.split(', ')

def get_friends(friends):
    if pd.isnull(friends):
        return ['by myself']
    return friends.split(', ')

def get_category(drink):
    if 'milk tea' in drink:
        return 'milk tea'
    elif 'milk' in drink:
        return 'milk'
    elif 'tea' in drink:
        return 'tea'
    elif 'smoothie' in drink or 'slush' in drink:
        return 'blended'
    else:
        return 'other'

boba['toppings'] = boba['toppings'].apply(get_toppings)
boba['friends'] = boba['friends'].apply(get_toppings)
boba['type'] = boba['drink'].apply(get_category)

# %%
month_map = {
    "january": 1,
    "february": 2,
    "march": 3,
    "april": 4,
    "may": 5,
    "june": 6,
    "july": 7,
    "august": 8,
    "september": 9,
    "october": 10,
    "november": 11,
    "december": 12
}

boba['month_num'] = boba['month'].map(month_map)
boba['date'] = boba['day'].astype(int)
boba['date_obj'] = boba.apply(lambda row: datetime(year=2025, month=row['month_num'], day=row['date']), axis=1)
boba['weekday'] = boba['date_obj'].apply(lambda d: d.weekday() + 1)

# %%
weekday_map = {
    1: "monday",
    2: "tuesday",
    3: "wednesday",
    4: "thursday",
    5: "friday",
    6: "saturday",
    7: "sunday"
}

boba['day of week'] = boba['weekday'].map(weekday_map)

# %%
boba
# Out:
#      month  day                     store                        drink  \
# 0  january    1  cafe bakery & restaurant           hong kong milk tea
# 1  january    2              1011 sip tea        lychee black milk tea
# 2  january    3                mr sun tea           earl grey milk tea
# 3  january    5           mandro teahouse       jasmine green milk tea
# 4  january    7                  teaspoon       jasmine green milk tea
# 5  january    7                      coco             green tea yakult
# 6  january   12                      coco             green tea yakult
# 7  january   13                     tptea  blended strawberry milk tea
#
#                        toppings               drink name  \
# 0                  [no topping]                      NaN
# 1                        [boba]                      NaN
# 2  [boba, pudding, grass jelly]  three brothers milk tea
# 3                     [pudding]                      NaN
# 4                        [boba]           creamy jasmine
# 5                  [no topping]                      NaN
# 6                  [no topping]                      NaN
# 7                        [boba]                      NaN
#
#                       friends   cost  size  rating      type  month_num  date  \
# 0  [sophia, mom, dad, wai po]  $4.75  16oz    8/10  milk tea          1     1
# 1            [sophia, wai po]  $5.50  16oz    7/10  milk tea          1     2
# 2                     [emily]  $4.00  22oz  8.5/10  milk tea          1     3
# 3                [emily, jas]  $5.00  22oz  8.5/10  milk tea          1     5
# 4                      [jeff]  $6.75  22oz    9/10  milk tea          1     7
# 5                      [jeff]  $7.50  22oz  7.5/10       tea          1     7
# 6                      [jeff]  $6.25  22oz    8/10       tea          1    12
# 7                   [anthony]  $6.75  22oz    8/10  milk tea          1    13
#
#     date_obj  weekday day of week
# 0 2025-01-01        3   wednesday
# 1 2025-01-02        4    thursday
# 2 2025-01-03        5      friday
# 3 2025-01-05        7      sunday
# 4 2025-01-07        2     tuesday
# 5 2025-01-07        2     tuesday
# 6 2025-01-12        7      sunday
# 7 2025-01-13        1      monday

# %%
boba_clean = boba.drop(columns=['month_num', 'date', 'weekday'])
boba_clean
# Out:
#      month  day                     store                        drink  \
# 0  january    1  cafe bakery & restaurant           hong kong milk tea
# 1  january    2              1011 sip tea        lychee black milk tea
# 2  january    3                mr sun tea           earl grey milk tea
# 3  january    5           mandro teahouse       jasmine green milk tea
# 4  january    7                  teaspoon       jasmine green milk tea
# 5  january    7                      coco             green tea yakult
# 6  january   12                      coco             green tea yakult
# 7  january   13                     tptea  blended strawberry milk tea
#
#                        toppings               drink name  \
# 0                  [no topping]                      NaN
# 1                        [boba]                      NaN
# 2  [boba, pudding, grass jelly]  three brothers milk tea
# 3                     [pudding]                      NaN
# 4                        [boba]           creamy jasmine
# 5                  [no topping]                      NaN
# 6                  [no topping]                      NaN
# 7                        [boba]                      NaN
#
#                       friends   cost  size  rating      type   date_obj  \
# 0  [sophia, mom, dad, wai po]  $4.75  16oz    8/10  milk tea 2025-01-01
# 1            [sophia, wai po]  $5.50  16oz    7/10  milk tea 2025-01-02
# 2                     [emily]  $4.00  22oz  8.5/10  milk tea 2025-01-03
# 3                [emily, jas]  $5.00  22oz  8.5/10  milk tea 2025-01-05
# 4                      [jeff]  $6.75  22oz    9/10  milk tea 2025-01-07
# 5                      [jeff]  $7.50  22oz  7.5/10       tea 2025-01-07
# 6                      [jeff]  $6.25  22oz    8/10       tea 2025-01-12
# 7                   [anthony]  $6.75  22oz    8/10  milk tea 2025-01-13
#
#   day of week
# 0   wednesday
# 1    thursday
# 2      friday
# 3      sunday
# 4     tuesday
# 5     tuesday
# 6      sunday
# 7      monday

# %% [markdown]
# ### stores

# %%
boba_clean.groupby('store').count()['drink'].sort_values(ascending=False).plot.bar();

# %% [markdown]
# ### day of the week

# %%
weekday_order = weekday_map.values()
boba_clean.groupby('day of week').count()['drink'].reindex(weekday_order).plot.bar();

# %%
calplot.calplot(boba_clean.groupby('date_obj').count()['drink'], cmap='YlGn');

# %% [markdown]
# ### unique drinks

# %%
boba_clean.groupby('drink')['day'].count().sort_values(ascending=False)
# Out:
# drink
# green tea yakult               2
# jasmine green milk tea         2
# blended strawberry milk tea    1
# earl grey milk tea             1
# hong kong milk tea             1
# lychee black milk tea          1
# Name: day, dtype: int64

# %%
boba_clean.groupby('drink')['day'].count().sort_values(ascending=False).plot.bar();

# %% [markdown]
# ### toppings

# %%
boba_clean['toppings'].dropna().explode().value_counts().plot.bar();

# %%
boba_clean['toppings'].dropna().value_counts().plot.bar();

# %% [markdown]
# ### friends

# %%
boba_clean['friends'].dropna().explode().value_counts().plot.bar();

# %%
boba_clean['friends'].dropna().value_counts().plot.bar();
