# %% [markdown]
# # Jasmine's Boba Tracker

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import re
from datetime import datetime
import calplot

# %%
boba_raw = pd.read_csv('data/boba_october.csv')

# %%
boba_raw
# Out:
#        month  day  location  \
# 0    January    3       ume
# 1    January    4  sunright
# 2    January   14      luxe
# 3    January   21       yun
# 4    January   21       yun
# ..       ...  ...       ...
# 110  October   10  moge tee
# 111  October   14  moge tee
# 112  October   16  moge tee
# 113  October   18  moge tee
# 114  October   19    sorate
#
#                                                  drink                people
# 0                         peach oolong milk tea w boba        sophia and mom
# 1                             original milk tea w boba     anthony and james
# 2    strawberry milk tea w strawberry heart jelly (...  adam lloyd and basil
# 3                              hojicha milk tea w boba                  oren
# 4                        rooibos milk tea w boba (zzz)      oren and anthony
# ..                                                 ...                   ...
# 110                                    milk tea w boba                   NaN
# 111                                    milk tea w boba                   NaN
# 112                     strawberry slush w cheese foam                   NaN
# 113                 uji matcha w boba and creme brulee                   NaN
# 114                                       matcha latte                 renee
#
# [115 rows x 5 columns]

# %%
boba_raw['month'] = boba_raw['month'].str.lower()

# %%
boba_raw
# Out:
#        month  day  location  \
# 0    january    3       ume
# 1    january    4  sunright
# 2    january   14      luxe
# 3    january   21       yun
# 4    january   21       yun
# ..       ...  ...       ...
# 110  october   10  moge tee
# 111  october   14  moge tee
# 112  october   16  moge tee
# 113  october   18  moge tee
# 114  october   19    sorate
#
#                                                  drink                people
# 0                         peach oolong milk tea w boba        sophia and mom
# 1                             original milk tea w boba     anthony and james
# 2    strawberry milk tea w strawberry heart jelly (...  adam lloyd and basil
# 3                              hojicha milk tea w boba                  oren
# 4                        rooibos milk tea w boba (zzz)      oren and anthony
# ..                                                 ...                   ...
# 110                                    milk tea w boba                   NaN
# 111                                    milk tea w boba                   NaN
# 112                     strawberry slush w cheese foam                   NaN
# 113                 uji matcha w boba and creme brulee                   NaN
# 114                                       matcha latte                 renee
#
# [115 rows x 5 columns]

# %%
boba = boba_raw.copy()

# %%
def get_name(drink):
    pattern = r'\(([^)]*)\)'
    name = re.findall(pattern, drink)
    if len(name) > 0:
        return name[0].strip()
    else:
        return np.nan

def get_base(drink):
    base = drink.split(' w ')[0]
    return base.strip()
    
def get_toppings(drink):
    t = re.split(' w ', drink)
    if len(t) > 1:
        t = re.split(r' \(', t[1])[0]
        t = t.split(' and ')
        return t
    else:
        return np.nan
    
def get_category(drink):
    if 'milk tea' in drink:
        return 'milk tea'
    elif 'milk' in drink:
        return 'milk'
    elif 'tea' in drink:
        return 'tea'
    elif 'smoothie' in drink or 'slush' in drink:
        return 'blended'
    else:
        return 'other'

# %%
# pd.isnull(boba['people'][113])

# %%
def get_friends(people):
    if pd.isnull(people):
        return []
    return people.replace(' and ', ' ').split(' ')

# %%
boba['name'] = boba['drink'].apply(get_name)
boba['base'] = boba['drink'].apply(get_base)
boba['toppings'] = boba['drink'].apply(get_toppings)
boba['type'] = boba['drink'].apply(get_category)

# %%
boba['friends'] = boba['people'].apply(get_friends)

# %%
month_map = {
    "january": 1,
    "february": 2,
    "march": 3,
    "april": 4,
    "may": 5,
    "june": 6,
    "july": 7,
    "august": 8,
    "september": 9,
    "october": 10,
    "november": 11,
    "december": 12
}

boba['month_num'] = boba['month'].map(month_map)
boba['date'] = boba['day'].astype(int)
boba['date_obj'] = boba.apply(lambda row: datetime(year=2024, month=row['month_num'], day=row['date']), axis=1)
boba['weekday'] = boba['date_obj'].apply(lambda d: d.weekday() + 1)

# %%
boba
# Out:
#        month  day  location  \
# 0    january    3       ume
# 1    january    4  sunright
# 2    january   14      luxe
# 3    january   21       yun
# 4    january   21       yun
# ..       ...  ...       ...
# 110  october   10  moge tee
# 111  october   14  moge tee
# 112  october   16  moge tee
# 113  october   18  moge tee
# 114  october   19    sorate
#
#                                                  drink                people  \
# 0                         peach oolong milk tea w boba        sophia and mom
# 1                             original milk tea w boba     anthony and james
# 2    strawberry milk tea w strawberry heart jelly (...  adam lloyd and basil
# 3                              hojicha milk tea w boba                  oren
# 4                        rooibos milk tea w boba (zzz)      oren and anthony
# ..                                                 ...                   ...
# 110                                    milk tea w boba                   NaN
# 111                                    milk tea w boba                   NaN
# 112                     strawberry slush w cheese foam                   NaN
# 113                 uji matcha w boba and creme brulee                   NaN
# 114                                       matcha latte                 renee
#
#              name                   base                  toppings      type  \
# 0             NaN  peach oolong milk tea                    [boba]  milk tea
# 1             NaN      original milk tea                    [boba]  milk tea
# 2    pink panther    strawberry milk tea  [strawberry heart jelly]  milk tea
# 3             NaN       hojicha milk tea                    [boba]  milk tea
# 4             zzz       rooibos milk tea                    [boba]  milk tea
# ..            ...                    ...                       ...       ...
# 110           NaN               milk tea                    [boba]  milk tea
# 111           NaN               milk tea                    [boba]  milk tea
# 112           NaN       strawberry slush             [cheese foam]   blended
# 113           NaN             uji matcha      [boba, creme brulee]     other
# 114           NaN           matcha latte                       NaN     other
#
#                   friends  month_num  date   date_obj  weekday
# 0           [sophia, mom]          1     3 2024-01-03        3
# 1        [anthony, james]          1     4 2024-01-04        4
# 2    [adam, lloyd, basil]          1    14 2024-01-14        7
# 3                  [oren]          1    21 2024-01-21        7
# 4         [oren, anthony]          1    21 2024-01-21        7
# ..                    ...        ...   ...        ...      ...
# 110                    []         10    10 2024-10-10        4
# 111                    []         10    14 2024-10-14        1
# 112                    []         10    16 2024-10-16        3
# 113                    []         10    18 2024-10-18        5
# 114               [renee]         10    19 2024-10-19        6
#
# [115 rows x 14 columns]

# %%
boba_clean = boba.drop(columns=['month', 'date', 'drink', 'month_num'])
boba_clean
# Out:
#      day  location                people          name                   base  \
# 0      3       ume        sophia and mom           NaN  peach oolong milk tea
# 1      4  sunright     anthony and james           NaN      original milk tea
# 2     14      luxe  adam lloyd and basil  pink panther    strawberry milk tea
# 3     21       yun                  oren           NaN       hojicha milk tea
# 4     21       yun      oren and anthony           zzz       rooibos milk tea
# ..   ...       ...                   ...           ...                    ...
# 110   10  moge tee                   NaN           NaN               milk tea
# 111   14  moge tee                   NaN           NaN               milk tea
# 112   16  moge tee                   NaN           NaN       strawberry slush
# 113   18  moge tee                   NaN           NaN             uji matcha
# 114   19    sorate                 renee           NaN           matcha latte
#
#                      toppings      type               friends   date_obj  \
# 0                      [boba]  milk tea         [sophia, mom] 2024-01-03
# 1                      [boba]  milk tea      [anthony, james] 2024-01-04
# 2    [strawberry heart jelly]  milk tea  [adam, lloyd, basil] 2024-01-14
# 3                      [boba]  milk tea                [oren] 2024-01-21
# 4                      [boba]  milk tea       [oren, anthony] 2024-01-21
# ..                        ...       ...                   ...        ...
# 110                    [boba]  milk tea                    [] 2024-10-10
# 111                    [boba]  milk tea                    [] 2024-10-14
# 112             [cheese foam]   blended                    [] 2024-10-16
# 113      [boba, creme brulee]     other                    [] 2024-10-18
# 114                       NaN     other               [renee] 2024-10-19
#
#      weekday
# 0          3
# 1          4
# 2          7
# 3          7
# 4          7
# ..       ...
# 110        4
# 111        1
# 112        3
# 113        5
# 114        6
#
# [115 rows x 10 columns]

# %% [markdown]
# ### Locations

# %%
boba_clean.groupby('location').count()['base'].sort_values(ascending=False).plot.bar()
# Out:
# <AxesSubplot:xlabel='location'>

# %% [markdown]
# ### Weekdays

# %%
boba_clean.groupby('weekday').count()['base'].plot.bar()
# Out:
# <AxesSubplot:xlabel='weekday'>

# %%
calplot.calplot(boba_clean.groupby('date_obj').count()['base'], cmap='YlGn')
# Out:
# (<Figure size 1250x170 with 2 Axes>,
#  array([<AxesSubplot:ylabel='2024'>], dtype=object))

# %% [markdown]
# ### Unique Drinks

# %%
boba_clean.groupby('base')['type'].count().sort_values(ascending=False)
# Out:
# base
# milk tea                                                                14
# strawberry milk tea                                                     11
# mango smoothie                                                           9
# jasmine milk tea                                                         6
# orange raspberry & passion fruit smoothie                                4
# strawberry smoothie                                                      3
# strawberry slush                                                         3
# lavender tea latte                                                       3
# earl gray milk tea                                                       2
# earl grey milk tea                                                       2
# black milk tea                                                           2
# matcha smoothie                                                          2
# matcha latte                                                             2
# mango slush                                                              2
# peach slushie                                                            2
# matcha slushie                                                           2
# gong king milk tea                                                       2
# thai tea                                                                 2
# iron goddess milk tea                                                    2
# uji matcha                                                               1
# peach oolong milk tea                                                    1
# original milk tea                                                        1
# peach & strawberry black tea                                             1
# peach and strawberry black tea                                           1
# taro milk tea                                                            1
# peach and strawberry slush                                               1
# taro smoothie                                                            1
# watermelon slush                                                         1
# strawberry milk                                                          1
# thai milk tea                                                            1
# peach smoothie                                                           1
# rooibos milk tea                                                         1
# rose high mountain milk tea                                              1
# strawberry green tea slush                                               1
# orange raspberry mango lime peach & pineapple smoothie (white gummi)     1
# pineapple slush                                                          1
# banana & maple espresso + milk                                           1
# oolong tea latte                                                         1
# oolong milk tea                                                          1
# blended matcha                                                           1
# brown sugar marble                                                       1
# classic milk tea                                                         1
# coconut milk tea                                                         1
# da hong pao oolong milk tea                                              1
# hojicha milk tea                                                         1
# hokkaido milk tea                                                        1
# jade black milk tea                                                      1
# jasmine green milk tea                                                   1
# korean strawberry milk                                                   1
# lychee green tea                                                         1
# mango coconut milk                                                       1
# mango coconut smoothie                                                   1
# mango green tea                                                          1
# mango matcha                                                             1
# mango milk tea                                                           1
# mango tea slush                                                          1
# banana milk                                                              1
# matcha soy milk tea                                                      1
# yakult lemon jasmine green tea                                           1
# Name: type, dtype: int64

# %%
boba_clean.groupby('base').count()['day'].sort_values(ascending=False).plot.bar()
# Out:
# <AxesSubplot:xlabel='base'>

# %% [markdown]
# ### Toppings

# %%
# all_toppings = boba_clean['toppings'].dropna().explode().to_list()
boba_clean['toppings'].dropna().explode().value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Friends

# %%
boba_clean['friends'].dropna().explode().value_counts().plot.bar()
# Out:
# <AxesSubplot:>
