# %% [markdown]
# # Jasmine's Boba Tracker

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import re
from datetime import datetime
import calplot

# %%
boba_raw = pd.read_csv('data/boba2025.csv')

# %%
boba_raw
# Out:
#         month  day    location  \
# 0     January    3         ume
# 1     January    4    sunright
# 2     January   14        luxe
# 3     January   21         yun
# 4     January   21         yun
# ..        ...  ...         ...
# 157  December   21       pekoe
# 158  December   27    sunright
# 159  December   29  mr sun tea
# 160  December   30       tptea
# 161  December   31      mandro
#
#                                                  drink                people
# 0                         peach oolong milk tea w boba        sophia and mom
# 1                             original milk tea w boba     anthony and james
# 2    strawberry milk tea w strawberry heart jelly (...  adam lloyd and basil
# 3                              hojicha milk tea w boba                  oren
# 4                        rooibos milk tea w boba (zzz)      oren and anthony
# ..                                                 ...                   ...
# 157                    matcha w crema and milk pudding                 lloyd
# 158  mango smoothie w jasmine tea jelly (mango fros...        sophia and mom
# 159         oolong milk tea w grass jelly and red bean         emily and jas
# 160                 blended strawberry milk tea w boba                 brian
# 161                      jasmine green milk tea w boba        sophia and mom
#
# [162 rows x 5 columns]

# %%
boba_raw['month'] = boba_raw['month'].str.lower()

# %%
boba_raw
# Out:
#         month  day    location  \
# 0     january    3         ume
# 1     january    4    sunright
# 2     january   14        luxe
# 3     january   21         yun
# 4     january   21         yun
# ..        ...  ...         ...
# 157  december   21       pekoe
# 158  december   27    sunright
# 159  december   29  mr sun tea
# 160  december   30       tptea
# 161  december   31      mandro
#
#                                                  drink                people
# 0                         peach oolong milk tea w boba        sophia and mom
# 1                             original milk tea w boba     anthony and james
# 2    strawberry milk tea w strawberry heart jelly (...  adam lloyd and basil
# 3                              hojicha milk tea w boba                  oren
# 4                        rooibos milk tea w boba (zzz)      oren and anthony
# ..                                                 ...                   ...
# 157                    matcha w crema and milk pudding                 lloyd
# 158  mango smoothie w jasmine tea jelly (mango fros...        sophia and mom
# 159         oolong milk tea w grass jelly and red bean         emily and jas
# 160                 blended strawberry milk tea w boba                 brian
# 161                      jasmine green milk tea w boba        sophia and mom
#
# [162 rows x 5 columns]

# %%
boba = boba_raw.copy()

# %%
def get_name(drink):
    pattern = r'\(([^)]*)\)'
    name = re.findall(pattern, drink)
    if len(name) > 0:
        return name[0].strip()
    else:
        return np.nan

def get_base(drink):
    base = drink.split(' w ')[0]
    return base.strip()
    
def get_toppings(drink):
    t = re.split(' w ', drink)
    if len(t) > 1:
        t = re.split(r' \(', t[1])[0]
        t = t.split(' and ')
        return t
    else:
        return np.nan
    
def get_category(drink):
    if 'milk tea' in drink:
        return 'milk tea'
    elif 'milk' in drink:
        return 'milk'
    elif 'tea' in drink:
        return 'tea'
    elif 'smoothie' in drink or 'slush' in drink:
        return 'blended'
    else:
        return 'other'

# %%
# pd.isnull(boba['people'][113])

# %%
def get_friends(people):
    if pd.isnull(people):
        return []
    return people.replace(' and ', ' ').split(' ')

# %%
boba['name'] = boba['drink'].apply(get_name)
boba['base'] = boba['drink'].apply(get_base)
boba['toppings'] = boba['drink'].apply(get_toppings)
boba['type'] = boba['drink'].apply(get_category)

# %%
boba['friends'] = boba['people'].apply(get_friends)

# %%
month_map = {
    "january": 1,
    "february": 2,
    "march": 3,
    "april": 4,
    "may": 5,
    "june": 6,
    "july": 7,
    "august": 8,
    "september": 9,
    "october": 10,
    "november": 11,
    "december": 12
}

boba['month_num'] = boba['month'].map(month_map)
boba['date'] = boba['day'].astype(int)
boba['date_obj'] = boba.apply(lambda row: datetime(year=2024, month=row['month_num'], day=row['date']), axis=1)
boba['weekday'] = boba['date_obj'].apply(lambda d: d.weekday() + 1)

# %%
boba
# Out:
#         month  day    location  \
# 0     january    3         ume
# 1     january    4    sunright
# 2     january   14        luxe
# 3     january   21         yun
# 4     january   21         yun
# ..        ...  ...         ...
# 157  december   21       pekoe
# 158  december   27    sunright
# 159  december   29  mr sun tea
# 160  december   30       tptea
# 161  december   31      mandro
#
#                                                  drink                people  \
# 0                         peach oolong milk tea w boba        sophia and mom
# 1                             original milk tea w boba     anthony and james
# 2    strawberry milk tea w strawberry heart jelly (...  adam lloyd and basil
# 3                              hojicha milk tea w boba                  oren
# 4                        rooibos milk tea w boba (zzz)      oren and anthony
# ..                                                 ...                   ...
# 157                    matcha w crema and milk pudding                 lloyd
# 158  mango smoothie w jasmine tea jelly (mango fros...        sophia and mom
# 159         oolong milk tea w grass jelly and red bean         emily and jas
# 160                 blended strawberry milk tea w boba                 brian
# 161                      jasmine green milk tea w boba        sophia and mom
#
#               name                         base                  toppings  \
# 0              NaN        peach oolong milk tea                    [boba]
# 1              NaN            original milk tea                    [boba]
# 2     pink panther          strawberry milk tea  [strawberry heart jelly]
# 3              NaN             hojicha milk tea                    [boba]
# 4              zzz             rooibos milk tea                    [boba]
# ..             ...                          ...                       ...
# 157            NaN                       matcha     [crema, milk pudding]
# 158  mango frostie               mango smoothie       [jasmine tea jelly]
# 159            NaN              oolong milk tea   [grass jelly, red bean]
# 160            NaN  blended strawberry milk tea                    [boba]
# 161            NaN       jasmine green milk tea                    [boba]
#
#          type               friends  month_num  date   date_obj  weekday
# 0    milk tea         [sophia, mom]          1     3 2024-01-03        3
# 1    milk tea      [anthony, james]          1     4 2024-01-04        4
# 2    milk tea  [adam, lloyd, basil]          1    14 2024-01-14        7
# 3    milk tea                [oren]          1    21 2024-01-21        7
# 4    milk tea       [oren, anthony]          1    21 2024-01-21        7
# ..        ...                   ...        ...   ...        ...      ...
# 157      milk               [lloyd]         12    21 2024-12-21        6
# 158       tea         [sophia, mom]         12    27 2024-12-27        5
# 159  milk tea          [emily, jas]         12    29 2024-12-29        7
# 160  milk tea               [brian]         12    30 2024-12-30        1
# 161  milk tea         [sophia, mom]         12    31 2024-12-31        2
#
# [162 rows x 14 columns]

# %%
boba_clean = boba.drop(columns=['month', 'date', 'drink', 'month_num'])
boba_clean
# Out:
#      day    location                people           name  \
# 0      3         ume        sophia and mom            NaN
# 1      4    sunright     anthony and james            NaN
# 2     14        luxe  adam lloyd and basil   pink panther
# 3     21         yun                  oren            NaN
# 4     21         yun      oren and anthony            zzz
# ..   ...         ...                   ...            ...
# 157   21       pekoe                 lloyd            NaN
# 158   27    sunright        sophia and mom  mango frostie
# 159   29  mr sun tea         emily and jas            NaN
# 160   30       tptea                 brian            NaN
# 161   31      mandro        sophia and mom            NaN
#
#                             base                  toppings      type  \
# 0          peach oolong milk tea                    [boba]  milk tea
# 1              original milk tea                    [boba]  milk tea
# 2            strawberry milk tea  [strawberry heart jelly]  milk tea
# 3               hojicha milk tea                    [boba]  milk tea
# 4               rooibos milk tea                    [boba]  milk tea
# ..                           ...                       ...       ...
# 157                       matcha     [crema, milk pudding]      milk
# 158               mango smoothie       [jasmine tea jelly]       tea
# 159              oolong milk tea   [grass jelly, red bean]  milk tea
# 160  blended strawberry milk tea                    [boba]  milk tea
# 161       jasmine green milk tea                    [boba]  milk tea
#
#                   friends   date_obj  weekday
# 0           [sophia, mom] 2024-01-03        3
# 1        [anthony, james] 2024-01-04        4
# 2    [adam, lloyd, basil] 2024-01-14        7
# 3                  [oren] 2024-01-21        7
# 4         [oren, anthony] 2024-01-21        7
# ..                    ...        ...      ...
# 157               [lloyd] 2024-12-21        6
# 158         [sophia, mom] 2024-12-27        5
# 159          [emily, jas] 2024-12-29        7
# 160               [brian] 2024-12-30        1
# 161         [sophia, mom] 2024-12-31        2
#
# [162 rows x 10 columns]

# %% [markdown]
# ### Locations

# %%
boba_clean.groupby('location').count()['base'].sort_values(ascending=False).plot.bar()
# Out:
# <AxesSubplot:xlabel='location'>

# %% [markdown]
# ### Weekdays

# %%
boba_clean.groupby('weekday').count()['base'].plot.bar()
# Out:
# <AxesSubplot:xlabel='weekday'>

# %%
calplot.calplot(boba_clean.groupby('date_obj').count()['base'], cmap='YlGn')
# Out:
# (<Figure size 1250x170 with 2 Axes>,
#  array([<AxesSubplot:ylabel='2024'>], dtype=object))

# %% [markdown]
# ### Unique Drinks

# %%
boba_clean.groupby('base')['type'].count().sort_values(ascending=False)
# Out:
# base
# milk tea                          17
# mango smoothie                    15
# strawberry milk tea               13
# jasmine milk tea                   7
# strawberry slush                   5
#                                   ..
# coconut milk tea                   1
# oolong tea latte                   1
# classic milk tea                   1
# brown sugar milk tea               1
# yakult lemon jasmine green tea     1
# Name: type, Length: 79, dtype: int64

# %%
boba_clean.groupby('base').count()['day'].sort_values(ascending=False).plot.bar()
# Out:
# <AxesSubplot:xlabel='base'>

# %% [markdown]
# ### Toppings

# %%
# all_toppings = boba_clean['toppings'].dropna().explode().to_list()
boba_clean['toppings'].dropna().explode().value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Friends

# %%
boba_clean['friends'].dropna().explode().value_counts().plot.bar()
# Out:
# <AxesSubplot:>
